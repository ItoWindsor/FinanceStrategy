# %%
import numpy as np
import matplotlib.pyplot as plt
import EuropeanOption as euro
import Strategy as strat

# %%
S0 = 100
K = 100
t = 0
T = 1
r = 5/100
q = 1/100
sigma = 20/100

model = "BS"

# %% [markdown]
# ### Test Call-Put

# %%
call = euro.EuropeanCallOption(model = "BS",S0 = S0, K = K, T = T, t = t, r = r, q = q, sigma = sigma)
put  = euro.EuropeanPutOption(model = "BS",S0 = S0, K = K, T = T, t = t, r = r, q = q, sigma = sigma)

# %%
call.plot_payoff()

# %%
put.plot_payoff()

# %% [markdown]
# ### Test Basic Strategies

# %%
K1 = 90
K2 = 110

# %%
CallSpread = strat.CallSpread(model = "BS", S0 = S0, t = t, T = T, r = r, q=q, sigma = sigma, K1 = K1, K2 = K2)

# %%
CallSpread.plot_payoff()
